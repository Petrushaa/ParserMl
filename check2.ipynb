# %%
import pandas as pd

# Загружаем CSV-файл
df = pd.read_csv("finam_news.csv")

df
# Out:
#                                                    text ticker price_news  \
# 0     Доля физлиц на рынке акций Мосбиржи снизилась ...   MOEX      162.7
# 1     Мосбиржа обсуждает с участниками рынка возможн...   MOEX     162.77
# 2     «ВК» вновь работает в Белоруссии в штатном реж...   VKCO      260.5
# 3     Акции «ВК» под давлением на фоне блокировки со...   VKCO      259.3
# 4     Чистая прибыль "Группы ЛСР" по РСБУ за 9 месяц...   LSRG      697.4
# ...                                                 ...    ...        ...
# 7206  Рынок упал вместе с «Газпромом», «выстрелила» ...   FESH      59.26
# 7207  Рынок упал вместе с «Газпромом», «выстрелила» ...   GAZP     128.77
# 7208  Группа «Аэрофлот» открывает регулярные рейсы м...   AFLT      59.17
# 7209  "Сбер" будет налаживать сотрудничество с Китае...   SBER        273
# 7210  "Росбанк" завершил присоединение к "Т-Банку" в...      T     2715.4
#
#      price_1d price_7d
# 0      161.78    162.5
# 1      161.77   162.48
# ...
