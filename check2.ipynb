# %%
import pandas as pd

# Загружаем CSV-файл
df = pd.read_csv("finam_news.csv")

df
# Out:
#                                                    text ticker price_news  \
# 0     Доля физлиц на рынке акций Мосбиржи снизилась ...   MOEX      162.7
# 1     Мосбиржа обсуждает с участниками рынка возможн...   MOEX     162.77
# 2     «ВК» вновь работает в Белоруссии в штатном реж...   VKCO      260.5
# 3     Акции «ВК» под давлением на фоне блокировки со...   VKCO      259.3
# 4     Чистая прибыль "Группы ЛСР" по РСБУ за 9 месяц...   LSRG      697.4
# ...                                                 ...    ...        ...
# 3841  ВТБ оценивает “стоимость” дивидендов в 1,1 п.п...   VTBR      98.88
# 3842  Выручка «ВсеИнструменты.ру» по МСФО в 2024 год...   VSEH       91.2
# 3843  Совет директоров «Европлана» рекомендовал 29 р...   LEAS      656.8
# 3844  Совет директоров «ЭсЭфАй» рекомендовал финальн...   SFIN     1499.6
# 3845  Российский контейнерный рынок снизился на 0,4%...   FESH      63.83
#
#      price_1d price_7d
# 0      161.78    162.5
# 1      161.77   162.48
# ...
